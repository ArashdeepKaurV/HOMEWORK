# %%
age = int(input("what is your age? "))

if age >= 25:
    print("Renting a car is more affordable")
if age <25 :
    print("Renting a car is very expensive")


if age >= 25:
    print("Renting a car is affordable")
elif age <25 or age >=18:
    print("Renting a car is very expensive")
elif age <18:
    print("You cannot legally rent a car")

string1 = "The quick brown fox jups over the lazy dog"

num_chars_in_string1 = 0
for c in string1:
    num_chars_in_string1 += 1

print("total number of character in string1 are", num_chars_in_string1)

vowels = "aeiouAEIOU"

vowels_in_string1 = ""
for c in string1 :
    if c in vowels:
        vowels_in_string1 += c

print("list of vowels in string1 are", vowels_in_string1)

couture = ["trousers", "blouse", "bandana", "cumber band", "blazer", "vest", "french beret", "scarf", "stole"]

panettone = {"cerise", "fuchsia", "aqua", "maple", "auburn", "burnt sienna", "gunmetal blue", "Dark Sapphire"}

for x in couture:
    for y in panettone:
        print(x,y)


sum_of_nums = 0
for i in range (1, 100):
    sum_of_nums += i

fruit_list = ["apple", "banana", "cherry"]

print(fruit_list[1])

fruit_list[0] = "kiwi"

fruit_list.append("orange")

fruit_list.insert(2, "lemon")

fruit_list.remove("banana")

updated_fruit_list = ["apple", "banana", "cherry", "orange", "kiwi", "melon", "mango"]

print(updated_fruit_list[-3:-1])

print(updated_fruit_list[3:6])

print(len(updated_fruit_list))

print(sorted(updated_fruit_list, reverse=True))
# Out:
# Renting a car is very expensive
# Renting a car is very expensive
# total number of character in string1 are 42
# list of vowels in string1 are euioouoeeao
# trousers fuchsia
# trousers burnt sienna
# trousers auburn
# trousers gunmetal blue
# trousers Dark Sapphire
# trousers aqua
# trousers cerise
# trousers maple
# blouse fuchsia
# blouse burnt sienna
# blouse auburn
# blouse gunmetal blue
# blouse Dark Sapphire
# blouse aqua
# blouse cerise
# blouse maple
# bandana fuchsia
# bandana burnt sienna
# bandana auburn
# bandana gunmetal blue
# bandana Dark Sapphire
# bandana aqua
# bandana cerise
# bandana maple
# cumber band fuchsia
# cumber band burnt sienna
# cumber band auburn
# cumber band gunmetal blue
# cumber band Dark Sapphire
# cumber band aqua
# cumber band cerise
# cumber band maple
# blazer fuchsia
# blazer burnt sienna
# blazer auburn
# blazer gunmetal blue
# blazer Dark Sapphire
# blazer aqua
# blazer cerise
# blazer maple
# vest fuchsia
# vest burnt sienna
# ...
